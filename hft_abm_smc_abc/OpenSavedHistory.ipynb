# %%
import sqlite3

import os
from pyabc import History


from pyabc import History
import  os

# %%
#db_path_store = "sqlite:////tmp/test1_test.db"
#abc.load("db_path_store", 1)
#C:\My Work Documents\Dissertation\pythonCodeVersions\
#ABC_HFT_Git\SMC_ABC_250TS_PlattSumStats_Adaptive2Norm\Adaptive_Distance250
#h_loaded = History("sqlite:///" + os.path.join("ABC_HFT_Git", "test1_test_1578239020.7823887.db"))

h_loaded = History("sqlite:///" +
                                "test1_test_1578239020.7823887.db")
print(h_loaded.all_runs())
# Out:
# [<ABCSMC(id=1, start_time=2020-01-05 17:43:56.194151, end_time=2020-01-06 17:06:59.260292)>]

# %%
from pyabc import History


#abc.load("db_path_store", 1)
#C:\My Work Documents\Dissertation\pythonCodeVersions\ABC_HFT_Git\SMC_ABC_250TS_PlattSumStats_2Norm\P2Norm_Distance
h_loaded = History("sqlite:///" + 
                   os.path.join("ABC_HFT_Git\SMC_ABC_250TS_PlattSumStats_Adaptive2Norm\Adaptive_Distance250",
                                "testAdaptive_Distance2501578586515.8353899.db"))
h_loaded.all_runs()
# Out:
# []

# %%
h_loaded = History("sqlite:///" + 
                   os.path.join("ABC_HFT_Git\AdaptivePNormDistance_2300",
                                "testAdaptivePNormDistance_23001578866654.6009083.db"))
h_loaded.all_runs()
# Out:
# [<ABCSMC(id=1, start_time=2020-01-13 00:04:14.742033, end_time=2020-01-13 00:45:29.143858)>]

# %%
#h is abc.history
# Evaluate the model probabililties
model_probabilities = h_loaded.get_model_probabilities()
model_probabilities
# Out:
# m    0
# t
# 0  1.0

# %%
import pyabc
pyabc.visualization.plot_model_probabilities(h_loaded)

# %%
from pyabc.visualization import plot_kde_matrix
df, w = h_loaded.get_distribution(m=0, t=0)
plot_kde_matrix(df, w);
#w

# %%
import numpy as np
np.mode(df["C_lambda"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-5ce41c29c6b5> in <module>
#       1 import numpy as np
# ----> 2 np.mode(df["C_lambda"])
#
# AttributeError: module 'numpy' has no attribute 'mode'

# %%
import matplotlib.pyplot as plt

def plot_history(history):
    fig, ax = plt.subplots()
    for t in range(history.max_t + 1):
        df, w = history.get_distribution(m=0, t=t)
    pyabc.visualization.plot_kde_1d(df, w, xmin=0, xmax=0.03,
    x='muSim', ax=ax,
    label="PDF t={}".format(t))
    ax.axvline(theta_true, color='k', linestyle='dashed', label="True value")
    ax.legend()


plot_history(h_loaded)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-f41a5ca03ee5> in <module>
#      12
#      13
# ---> 14 plot_history(h_loaded)
#
# <ipython-input-32-f41a5ca03ee5> in plot_history(history)
#       8     x='muSim', ax=ax,
#       9     label="PDF t={}".format(t))
# ---> 10     ax.axvline(theta_true, color='k', linestyle='dashed', label="True value")
#      11     ax.legend()
#      12
#
# NameError: name 'theta_true' is not defined
